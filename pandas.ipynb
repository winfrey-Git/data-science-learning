# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\Winnie\Downloads\archive\Student_performance.csv")
df
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1002   18       0          0                  1        15.408756
# 2          1003   15       0          2                  3         4.210570
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# ...         ...  ...     ...        ...                ...              ...
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1002   18       0          0                  1        15.408756
# 2          1003   15       0          2                  3         4.210570
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# ...         ...  ...     ...        ...                ...              ...
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
# ...

# %%
df.drop(columns = "	Music")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.drop(columns = "	Music")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
# ...

# %%
df.head()
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# ...

# %%
df=to_drop =['Sports',
          'Music',]
df
# Out:
# ['Sports', 'Music']

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df.head()
#
# AttributeError: 'list' object has no attribute 'head'

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\Winnie\Downloads\Student_performance_data _ (1).csv")
print(df.head())
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# ...

# %%
print(df)
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1002   18       0          0                  1        15.408756
# 2          1003   15       0          2                  3         4.210570
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# ...         ...  ...     ...        ...                ...              ...
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
# ...

# %%
df.to_csv(r"C:\Users\Winnie\Downloads\Student_performance_data _ (1).csv", index=False)

# %%
df.head()
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# ...

# %%
df.tail(n=10)
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 2382       3383   16       0          0                  3        13.941823
# 2383       3384   16       1          2                  2        11.736409
# 2384       3385   15       1          0                  1        16.655581
# 2385       3386   16       1          0                  1         1.445434
# 2386       3387   16       0          0                  2        13.814021
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
#       Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# ...

# %%
df.tail()
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
#       Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 2387         2         0                4                1       0      0
# 2388         4         1                4                0       1      0
# 2389        20         0                2                0       0      0
# 2390        17         0                2                0       1      1
# 2391        13         0                2                0       0      0
#
#       Volunteering       GPA  GradeClass
# ...

# %%
#understanding data using describe function
df.describe()
# Out:
#          StudentID          Age       Gender    Ethnicity  ParentalEducation  \
# count  2392.000000  2392.000000  2392.000000  2392.000000        2392.000000
# mean   2196.500000    16.468645     0.510870     0.877508           1.746237
# std     690.655244     1.123798     0.499986     1.028476           1.000411
# min    1001.000000    15.000000     0.000000     0.000000           0.000000
# 25%    1598.750000    15.000000     0.000000     0.000000           1.000000
# 50%    2196.500000    16.000000     1.000000     0.000000           2.000000
# 75%    2794.250000    17.000000     1.000000     2.000000           2.000000
# max    3392.000000    18.000000     1.000000     3.000000           4.000000
#
#        StudyTimeWeekly     Absences     Tutoring  ParentalSupport  \
# count      2392.000000  2392.000000  2392.000000      2392.000000
# mean          9.771992    14.541388     0.301421         2.122074
# std           5.652774     8.467417     0.458971         1.122813
# ...

# %%
df.describe(percentiles=[0.3, 0.5, 0.7])
# Out:
#          StudentID          Age       Gender    Ethnicity  ParentalEducation  \
# count  2392.000000  2392.000000  2392.000000  2392.000000        2392.000000
# mean   2196.500000    16.468645     0.510870     0.877508           1.746237
# std     690.655244     1.123798     0.499986     1.028476           1.000411
# min    1001.000000    15.000000     0.000000     0.000000           0.000000
# 30%    1718.300000    16.000000     0.000000     0.000000           1.000000
# 50%    2196.500000    16.000000     1.000000     0.000000           2.000000
# 70%    2674.700000    17.000000     1.000000     1.000000           2.000000
# max    3392.000000    18.000000     1.000000     3.000000           4.000000
#
#        StudyTimeWeekly     Absences     Tutoring  ParentalSupport  \
# count      2392.000000  2392.000000  2392.000000      2392.000000
# mean          9.771992    14.541388     0.301421         2.122074
# std           5.652774     8.467417     0.458971         1.122813
# ...

# %%
df.describe(include=[int])
# Out:
#          StudentID          Age       Gender    Ethnicity  ParentalEducation  \
# count  2392.000000  2392.000000  2392.000000  2392.000000        2392.000000
# mean   2196.500000    16.468645     0.510870     0.877508           1.746237
# std     690.655244     1.123798     0.499986     1.028476           1.000411
# min    1001.000000    15.000000     0.000000     0.000000           0.000000
# 25%    1598.750000    15.000000     0.000000     0.000000           1.000000
# 50%    2196.500000    16.000000     1.000000     0.000000           2.000000
# 75%    2794.250000    17.000000     1.000000     2.000000           2.000000
# max    3392.000000    18.000000     1.000000     3.000000           4.000000
#
#           Absences     Tutoring  ParentalSupport  Extracurricular  \
# count  2392.000000  2392.000000      2392.000000      2392.000000
# mean     14.541388     0.301421         2.122074         0.383361
# std       8.467417     0.458971         1.122813         0.486307
# ...

# %%
df.describe(exclude=[int])
# Out:
#        StudyTimeWeekly          GPA   GradeClass
# count      2392.000000  2392.000000  2392.000000
# mean          9.771992     1.906186     2.983696
# std           5.652774     0.915156     1.233908
# min           0.001057     0.000000     0.000000
# 25%           5.043079     1.174803     2.000000
# 50%           9.705363     1.893393     4.000000
# 75%          14.408410     2.622216     4.000000
# max          19.978094     4.000000     4.000000

# %%
df.describe().T
# Out:
#                     count         mean         std          min          25%  \
# StudentID          2392.0  2196.500000  690.655244  1001.000000  1598.750000
# Age                2392.0    16.468645    1.123798    15.000000    15.000000
# Gender             2392.0     0.510870    0.499986     0.000000     0.000000
# Ethnicity          2392.0     0.877508    1.028476     0.000000     0.000000
# ParentalEducation  2392.0     1.746237    1.000411     0.000000     1.000000
# StudyTimeWeekly    2392.0     9.771992    5.652774     0.001057     5.043079
# Absences           2392.0    14.541388    8.467417     0.000000     7.000000
# Tutoring           2392.0     0.301421    0.458971     0.000000     0.000000
# ParentalSupport    2392.0     2.122074    1.122813     0.000000     1.000000
# Extracurricular    2392.0     0.383361    0.486307     0.000000     0.000000
# Sports             2392.0     0.303512    0.459870     0.000000     0.000000
# ...

# %%
df.info(show_counts=True, memory_usage=True, verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   StudentID          2392 non-null   int64
#  1   Age                2392 non-null   int64
#  2   Gender             2392 non-null   int64
#  3   Ethnicity          2392 non-null   int64
#  4   ParentalEducation  2392 non-null   int64
#  5   StudyTimeWeekly    2392 non-null   float64
#  6   Absences           2392 non-null   int64
#  7   Tutoring           2392 non-null   int64
#  8   ParentalSupport    2392 non-null   int64
#  9   Extracurricular    2392 non-null   int64
#  10  Sports             2392 non-null   int64
#  11  Music              2392 non-null   int64
#  12  Volunteering       2392 non-null   int64
#  13  GPA                2392 non-null   float64
#  14  GradeClass         2392 non-null   float64
# dtypes: float64(3), int64(12)
# memory usage: 280.4 KB

# %%
df.shape[0]
# Out:
# 2392

# %%
df.shape[1]
# Out:
# 15

# %%
df.shape
# Out:
# (2392, 15)

# %%
df.columns
# Out:
# Index(['StudentID', 'Age', 'Gender', 'Ethnicity', 'ParentalEducation',
#        'StudyTimeWeekly', 'Absences', 'Tutoring', 'ParentalSupport',
#        'Extracurricular', 'Sports', 'Music', 'Volunteering', 'GPA',
#        'GradeClass'],
#       dtype='object')

# %%
list(df.columns)
# Out:
# ['StudentID',
#  'Age',
#  'Gender',
#  'Ethnicity',
#  'ParentalEducation',
#  'StudyTimeWeekly',
#  'Absences',
#  'Tutoring',
#  'ParentalSupport',
#  'Extracurricular',
#  'Sports',
#  'Music',
#  'Volunteering',
#  'GPA',
#  'GradeClass']

# %%
df2= df.copy()
df2.loc[2:5, 'Age']= None
df2.head(7)
# Out:
#    StudentID   Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001  17.0       1          0                  2        19.833723
# 1       1002  18.0       0          0                  1        15.408756
# 2       1003   NaN       0          2                  3         4.210570
# 3       1004   NaN       1          0                  3        10.028829
# 4       1005   NaN       1          0                  2         4.672495
# 5       1006   NaN       0          0                  1         8.191219
# 6       1007  15.0       0          1                  1        15.601680
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# ...

# %%
df2.isnull().head(7)
# Out:
#    StudentID    Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0      False  False   False      False              False            False
# 1      False  False   False      False              False            False
# 2      False   True   False      False              False            False
# 3      False   True   False      False              False            False
# 4      False   True   False      False              False            False
# 5      False   True   False      False              False            False
# 6      False  False   False      False              False            False
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0     False     False            False            False   False  False
# 1     False     False            False            False   False  False
# 2     False     False            False            False   False  False
# 3     False     False            False            False   False  False
# ...

# %%
df2.isnull().sum()
# Out:
# StudentID            0
# Age                  4
# Gender               0
# Ethnicity            0
# ParentalEducation    0
# StudyTimeWeekly      0
# Absences             0
# Tutoring             0
# ParentalSupport      0
# Extracurricular      0
# Sports               0
# Music                0
# Volunteering         0
# GPA                  0
# GradeClass           0
# dtype: int64

# %%
df2.isnull()
# Out:
#       StudentID    Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0         False  False   False      False              False            False
# 1         False  False   False      False              False            False
# 2         False   True   False      False              False            False
# 3         False   True   False      False              False            False
# 4         False   True   False      False              False            False
# ...         ...    ...     ...        ...                ...              ...
# 2387      False  False   False      False              False            False
# 2388      False  False   False      False              False            False
# 2389      False  False   False      False              False            False
# 2390      False  False   False      False              False            False
# 2391      False  False   False      False              False            False
#
# ...

# %%
df2.isnull().sum().sum()
# Out:
# 4

# %%
#slicing and extracting data

#isolating data of one column 
df['Age']
# Out:
# 0       17
# 1       18
# 2       15
# 3       17
# 4       17
#         ..
# 2387    18
# 2388    17
# 2389    16
# 2390    16
# 2391    16
# Name: Age, Length: 2392, dtype: int64

# %%
#isolating data of two columns
df[['Age', 'Gender']]
# Out:
#       Age  Gender
# 0      17       1
# 1      18       0
# 2      15       0
# 3      17       1
# 4      17       1
# ...   ...     ...
# 2387   18       1
# 2388   17       0
# 2389   16       1
# 2390   16       1
# 2391   16       1
#
# [2392 rows x 2 columns]

# %%
#isolating data of one row
df[df.index==1]
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 1       1002   18       0          0                  1        15.408756
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 1         0         0                1                0       0      0
#
#    Volunteering       GPA  GradeClass
# 1             0  3.042915         1.0

# %%
#isolating two or more rows using []

df[df.index.isin(range(2,10))]
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
# 5       1006   18       0          0                  1         8.191219
# 6       1007   15       0          1                  1        15.601680
# 7       1008   15       1          1                  4        15.424496
# 8       1009   17       0          0                  0         4.562008
# 9       1010   16       1          0                  1        18.444466
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
# ...

# %%
# using .loc[] and .iloc[] to fetch rows

df2.index = range(1, 2393)

# %%
df2.loc[1]
# Out:
# StudentID            1001.000000
# Age                    17.000000
# Gender                  1.000000
# Ethnicity               0.000000
# ParentalEducation       2.000000
# StudyTimeWeekly        19.833723
# Absences                7.000000
# Tutoring                1.000000
# ParentalSupport         2.000000
# Extracurricular         0.000000
# Sports                  0.000000
# Music                   1.000000
# Volunteering            0.000000
# GPA                     2.929196
# GradeClass              2.000000
# Name: 1, dtype: float64

# %%
df.iloc[1]
# Out:
# StudentID            1002.000000
# Age                    18.000000
# Gender                  0.000000
# Ethnicity               0.000000
# ParentalEducation       1.000000
# StudyTimeWeekly        15.408756
# Absences                0.000000
# Tutoring                0.000000
# ParentalSupport         1.000000
# Extracurricular         0.000000
# Sports                  0.000000
# Music                   0.000000
# Volunteering            0.000000
# GPA                     3.042915
# GradeClass              1.000000
# Name: 1, dtype: float64

# %%
df.head()
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# ...

# %%
df2.loc[100:300]
# Out:
#      StudentID   Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 100       1100  15.0       0          0                  1        17.500174
# 101       1101  17.0       1          2                  1         6.029124
# 102       1102  16.0       1          0                  3         1.891127
# 103       1103  16.0       0          1                  1        15.167695
# 104       1104  18.0       1          0                  2        12.120277
# ..         ...   ...     ...        ...                ...              ...
# 296       1296  18.0       1          0                  2         0.767277
# 297       1297  16.0       0          0                  0        17.415943
# 298       1298  17.0       1          0                  1        10.254998
# 299       1299  15.0       1          1                  3         7.965005
# 300       1300  18.0       0          1                  1         9.943346
#
# ...

# %%
df2.iloc[100:300]
# Out:
#      StudentID   Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 101       1101  17.0       1          2                  1         6.029124
# 102       1102  16.0       1          0                  3         1.891127
# 103       1103  16.0       0          1                  1        15.167695
# 104       1104  18.0       1          0                  2        12.120277
# 105       1105  16.0       1          1                  0        11.406250
# ..         ...   ...     ...        ...                ...              ...
# 296       1296  18.0       1          0                  2         0.767277
# 297       1297  16.0       0          0                  0        17.415943
# 298       1298  17.0       1          0                  1        10.254998
# 299       1299  15.0       1          1                  3         7.965005
# 300       1300  18.0       0          1                  1         9.943346
#
# ...

# %%
#Isolating rows using a list in pandas with .loc[]
df2.loc[[100, 200, 300]]
# Out:
#      StudentID   Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 100       1100  15.0       0          0                  1        17.500174
# 200       1200  17.0       1          2                  3         1.573954
# 300       1300  18.0       0          1                  1         9.943346
#
#      Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 100        24         0                2                0       0      0
# 200        28         0                3                1       0      0
# 300        12         1                1                0       0      0
#
#      Volunteering       GPA  GradeClass
# 100             0  0.722057         4.0
# 200             0  0.581356         4.0
# 300             0  1.733972         4.0

# %%
#Isolating rows using a list in pandas with .iloc[]
df2.iloc[[100, 200, 300]]
# Out:
#      StudentID   Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 101       1101  17.0       1          2                  1         6.029124
# 201       1201  17.0       0          1                  2        10.546218
# 301       1301  15.0       1          0                  1        13.348311
#
#      Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 101        23         1                1                1       1      0
# 201        18         0                1                0       0      1
# 301        28         0                3                1       0      0
#
#      Volunteering       GPA  GradeClass
# 101             1  1.271230         4.0
# 201             0  1.643462         4.0
# 301             0  1.113849         4.0

# %%
df2.loc[100:110, ['Age', 'Absences', 'Tutoring']]
# Out:
#       Age  Absences  Tutoring
# 100  15.0        24         0
# 101  17.0        23         1
# 102  16.0         6         0
# 103  16.0        27         0
# 104  18.0        20         1
# 105  16.0        29         0
# 106  16.0        14         0
# 107  16.0        18         0
# 108  18.0        15         0
# 109  16.0        24         1
# 110  17.0        12         1

# %%
df2.iloc[100:110, 1:8:2]
# Out:
#       Age  Ethnicity  StudyTimeWeekly  Tutoring
# 101  17.0          2         6.029124         1
# 102  16.0          0         1.891127         0
# 103  16.0          1        15.167695         0
# 104  18.0          0        12.120277         1
# 105  16.0          1        11.406250         0
# 106  16.0          2         1.071531         0
# 107  16.0          3         2.809980         0
# 108  18.0          0        12.450988         0
# 109  16.0          2         4.156477         1
# 110  17.0          2        10.081402         1

# %%
df2.loc[2380:, ['Age', 'Ethnicity', 'StudyTimeWeekly', 'Tutoring']]
# Out:
#        Age  Ethnicity  StudyTimeWeekly  Tutoring
# 2380  18.0          0        16.534553         0
# 2381  16.0          0         2.138397         0
# 2382  15.0          2        10.095086         0
# 2383  16.0          0        13.941823         0
# 2384  16.0          2        11.736409         1
# 2385  15.0          0        16.655581         1
# 2386  16.0          0         1.445434         0
# 2387  16.0          0        13.814021         0
# 2388  18.0          0        10.680555         0
# 2389  17.0          0         7.583217         1
# 2390  16.0          0         6.805500         0
# 2391  16.0          1        12.416653         0
# 2392  16.0          0        17.819907         0

# %%
df2.iloc[2380: , 1:8:2]
# Out:
#        Age  Ethnicity  StudyTimeWeekly  Tutoring
# 2381  16.0          0         2.138397         0
# 2382  15.0          2        10.095086         0
# 2383  16.0          0        13.941823         0
# 2384  16.0          2        11.736409         1
# 2385  15.0          0        16.655581         1
# 2386  16.0          0         1.445434         0
# 2387  16.0          0        13.814021         0
# 2388  18.0          0        10.680555         0
# 2389  17.0          0         7.583217         1
# 2390  16.0          0         6.805500         0
# 2391  16.0          1        12.416653         0
# 2392  16.0          0        17.819907         0

# %%
df2.loc[df['Age']== 16, ['Age']]=17.0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 df2.loc[df['Age']== 16, ['Age']]=17.0
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:907, in _LocationIndexer.__setitem__(self, key, value)
#     905     maybe_callable = com.apply_if_callable(key, self.obj)
#     906     key = self._check_deprecated_callable_usage(key, maybe_callable)
# --> 907 indexer = self._get_setitem_indexer(key)
#     908 self._has_valid_setitem_indexer(key)
#     910 iloc = self if self.name == "iloc" else self.obj.iloc
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:780, in _LocationIndexer._get_setitem_indexer(self, key)
#     776 if isinstance(key, range):
#     777     # GH#45479 test_loc_setitem_range_key
#     778     key = list(key)
# ...

# %%
#conditional slicing(that fits certain conditions)

df[df.Age==18]
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 1          1002   18       0          0                  1        15.408756
# 5          1006   18       0          0                  1         8.191219
# 14         1015   18       1          0                  1        11.197811
# 16         1017   18       0          3                  1        10.098656
# 17         1018   18       1          0                  0         3.528238
# ...         ...  ...     ...        ...                ...              ...
# 2373       3374   18       0          3                  2        19.088954
# 2375       3376   18       0          0                  2        18.925290
# 2377       3378   18       0          0                  2        12.749976
# 2379       3380   18       1          0                  2        16.534553
# 2387       3388   18       1          0                  3        10.680555
#
# ...

# %%
#df[df['Absences']==0]
df[df.Absences==0]
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 1          1002   18       0          0                  1        15.408756
# 5          1006   18       0          0                  1         8.191219
# 9          1010   16       1          0                  1        18.444466
# 91         1092   18       1          0                  2         7.724728
# 162        1163   18       0          0                  2        13.084716
# ...         ...  ...     ...        ...                ...              ...
# 2222       3223   16       0          0                  2         9.766698
# 2244       3245   18       1          0                  1        18.487087
# 2267       3268   18       1          2                  2         7.598010
# 2316       3317   16       1          2                  0         6.969560
# 2319       3320   17       0          0                  2         9.285447
#
# ...

# %%
df.loc[df['Age']>16, ['StudyTimeWeekly', 'Ethnicity',  'Music', 'Age']]
# Out:
#       StudyTimeWeekly  Ethnicity  Music  Age
# 0           19.833723          0      1   17
# 1           15.408756          0      0   18
# 3           10.028829          0      0   17
# 4            4.672495          0      0   17
# 5            8.191219          0      0   18
# ...               ...        ...    ...  ...
# 2376        14.667230          2      0   17
# 2377        12.749976          0      0   18
# 2379        16.534553          0      0   18
# 2387        10.680555          0      0   18
# 2388         7.583217          0      0   17
#
# [1169 rows x 4 columns]

# %%
#CLEANING DATA USING PANDAS
df2.isnull().sum()
# Out:
# StudentID            0
# Age                  4
# Gender               0
# Ethnicity            0
# ParentalEducation    0
# StudyTimeWeekly      0
# Absences             0
# Tutoring             0
# ParentalSupport      0
# Extracurricular      0
# Sports               0
# Music                0
# Volunteering         0
# GPA                  0
# GradeClass           0
# dtype: int64

# %%
#Dropping missing values
df3=df2.copy()
df3= df3.dropna()
df3.head()
df3.shape
# Out:
# (2388, 15)

# %%
df3= df2.copy()
df3.dropna(inplace=True, axis=1)
df3.head()
df3.shape
# Out:
# (2392, 14)

# %%
df3.head()
# Out:
#    StudentID  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  Absences  \
# 1       1001       1          0                  2        19.833723         7
# 2       1002       0          0                  1        15.408756         0
# 3       1003       0          2                  3         4.210570        26
# 4       1004       1          0                  3        10.028829        14
# 5       1005       1          0                  2         4.672495        17
#
#    Tutoring  ParentalSupport  Extracurricular  Sports  Music  Volunteering  \
# 1         1                2                0       0      1             0
# 2         0                1                0       0      0             0
# 3         0                2                0       0      0             0
# 4         0                3                1       0      0             0
# 5         1                3                0       0      0             0
#
#         GPA  GradeClass
# ...

# %%
#droping both rows and columns with null values

df3 = df2.copy()
df3.dropna(inplace= True, how ='all')
df3.shape
# Out:
# (2392, 15)

# %%
#replacing missing values
df3 = df2.copy()
mean_value= df3['Age'].mean()
# Fill missing values using .fillna()
df3 = df3.fillna(mean_value)

# %%
#dealing with duplicate data

df3= pd.concat([df2, df2])
df3.shape
# Out:
# (4784, 15)

# %%
df3 = df3.drop_duplicates()
df3.shape
# Out:
# (2392, 15)

# %%
df3.rename(columns = {'Age':'A'}, inplace = True)
df3.head()
# Out:
#    StudentID     A  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 1       1001  17.0       1          0                  2        19.833723
# 2       1002  18.0       0          0                  1        15.408756
# 3       1003   NaN       0          2                  3         4.210570
# 4       1004   NaN       1          0                  3        10.028829
# 5       1005   NaN       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 1         7         1                2                0       0      1
# 2         0         0                1                0       0      0
# 3        26         0                2                0       0      0
# 4        14         0                3                1       0      0
# 5        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 1             0  2.929196         2.0
# ...

# %%
df.mean()
# Out:
# StudentID            2196.500000
# Age                    16.468645
# Gender                  0.510870
# Ethnicity               0.877508
# ParentalEducation       1.746237
# StudyTimeWeekly         9.771992
# Absences               14.541388
# Tutoring                0.301421
# ParentalSupport         2.122074
# Extracurricular         0.383361
# Sports                  0.303512
# Music                   0.196906
# Volunteering            0.157191
# GPA                     1.906186
# GradeClass              2.983696
# dtype: float64

# %%
df.median()
# Out:
# StudentID            2196.500000
# Age                    16.000000
# Gender                  1.000000
# Ethnicity               0.000000
# ParentalEducation       2.000000
# StudyTimeWeekly         9.705363
# Absences               15.000000
# Tutoring                0.000000
# ParentalSupport         2.000000
# Extracurricular         0.000000
# Sports                  0.000000
# Music                   0.000000
# Volunteering            0.000000
# GPA                     1.893393
# GradeClass              4.000000
# dtype: float64

# %%
df.mode()
# Out:
#       StudentID   Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001  15.0     1.0        0.0                2.0         0.001057
# 1          1002   NaN     NaN        NaN                NaN         0.004859
# 2          1003   NaN     NaN        NaN                NaN         0.008031
# 3          1004   NaN     NaN        NaN                NaN         0.008206
# 4          1005   NaN     NaN        NaN                NaN         0.014337
# ...         ...   ...     ...        ...                ...              ...
# 2387       3388   NaN     NaN        NaN                NaN        19.939810
# 2388       3389   NaN     NaN        NaN                NaN        19.948459
# 2389       3390   NaN     NaN        NaN                NaN        19.968425
# 2390       3391   NaN     NaN        NaN                NaN        19.972346
# 2391       3392   NaN     NaN        NaN                NaN        19.978094
#
# ...

# %%
#creating a new column based on existing ones

df2['Age_Ttutoring_Ratio'] = df2['Age']*df2['Tutoring']
df2.head()
# Out:
#    StudentID   Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 1       1001  17.0       1          0                  2        19.833723
# 2       1002  18.0       0          0                  1        15.408756
# 3       1003   NaN       0          2                  3         4.210570
# 4       1004   NaN       1          0                  3        10.028829
# 5       1005   NaN       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 1         7         1                2                0       0      1
# 2         0         0                1                0       0      0
# 3        26         0                2                0       0      0
# 4        14         0                3                1       0      0
# 5        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass  Age_Ttutoring_Ratio
# ...

# %%
#counting using .value_counts()

df['Age'].value_counts()
# Out:
# Age
# 15    630
# 16    593
# 17    587
# 18    582
# Name: count, dtype: int64

# %%
#Adding the normalize argument returns proportions instead of absolute counts.


df['Age'].value_counts(normalize=True)
# Out:
# Age
# 15    0.263378
# 16    0.247910
# 17    0.245401
# 18    0.243311
# Name: proportion, dtype: float64

# %%
#Turn off automatic sorting of results using sort argument (True by default). The default sorting is based on the counts in descending order.
df['Age'].value_counts(sort=False)
# Out:
# Age
# 17    587
# 18    582
# 15    630
# 16    593
# Name: count, dtype: int64

# %%
df.value_counts(subset=['Age', 'Gender'])
# Out:
# Age  Gender
# 15   0         338
# 17   1         315
# 16   1         310
# 18   1         305
# 15   1         292
# 16   0         283
# 18   0         277
# 17   0         272
# Name: count, dtype: int64

# %%
#Aggregating data with .groupby() in pandas
import pandas as pd

df = pd.read_csv(r"C:\Users\Winnie\Downloads\Student_performance_data _ (1).csv")

df.groupby('Age').mean()
# Out:
#        StudentID    Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# Age
# 15   2214.565079  0.463492   0.920635           1.715873         9.837934
# 16   2227.590219  0.522766   0.871838           1.723440         9.852194
# 17   2209.107325  0.536627   0.884157           1.775128         9.573588
# 18   2132.551546  0.524055   0.829897           1.773196         9.819003
#
#       Absences  Tutoring  ParentalSupport  Extracurricular    Sports  \
# Age
# 15   14.550794  0.298413         2.020635         0.390476  0.347619
# 16   14.807757  0.318718         2.150084         0.403035  0.295110
# 17   14.419080  0.301533         2.221465         0.376491  0.275980
# 18   14.383162  0.286942         2.103093         0.362543  0.292096
#
#         Music  Volunteering       GPA  GradeClass
# Age
# 15   0.192063      0.161905  1.898509    2.996825
# 16   0.204047      0.134907  1.907534    2.981450
# 17   0.204429      0.165247  1.927030    2.981261
# ...

# %%
df.groupby (['Age', 'Absences']).mean()
# Out:
#                 StudentID    Gender  Ethnicity  ParentalEducation  \
# Age Absences
# 15  0         2114.375000  0.250000   0.750000           1.750000
#     1         2258.916667  0.458333   1.166667           2.041667
#     2         2104.480000  0.560000   0.680000           1.600000
#     3         2007.880000  0.440000   0.840000           2.040000
#     4         2334.789474  0.210526   1.105263           1.684211
# ...                   ...       ...        ...                ...
# 18  25        2106.416667  0.541667   1.000000           1.458333
#     26        1922.318182  0.454545   0.545455           1.863636
#     27        1912.625000  0.250000   0.625000           1.500000
#     28        2424.777778  0.666667   0.444444           1.666667
#     29        2178.714286  0.428571   1.000000           2.142857
#
#               StudyTimeWeekly  Tutoring  ParentalSupport  Extracurricular  \
# Age Absences
# ...

# %%
#data visualization
df[['Absences', 'Age']].plot.line(figsize=(10,20), color={'Absences':'Red', 'Age':'Blue'))
# Out:
# <Axes: >
